# %%
# Print out game rules 
def rules():
    print('Welcome to tic tac toe')
    print('Player 1 = X & Player 2 = O')
    print('Select a position from 1 to 9 to place your respective mark')
    print('Player who creates first horizontal,vertical or diagonal line of XXX or OOO, Wins!')

# %%
# Print out board 
board =    [[1,2,3],
            [4,5,6],
            [7,8,9]]
def boards(board):
    
    for i in board:
        for j in i:
            print(j, end = " ")
        print()

# %%
# Function to take in  Player 1's choice
def user_choice1():
    choice1 = False
    p1_choice = '0'
    board =    [[1,2,3],[4,5,6],[7,8,9]] 

    while choice1 == False:
        
        p1_choice = input('Player 1 : Please select which position you would like to place your X ,from 1 to 9')
        
    
        if p1_choice.isdigit()==False:
            print('Please enter a digit')
        else:
            if int(p1_choice) in range(0,10):
                choice1 = True
            else:
                print('Please select a valid position')
    return int(p1_choice)

# %%
# Function to take Player 2's position choice
def user_choice2():
    choice2 = False
    p2_choice = '0'
    
    while choice2 == False:
        p2_choice = input('Player 2 : Please select which position you would like to place your O ,from 1 to 9')
        
    
        if p2_choice.isdigit()==False:
            print('Please enter a digit')
        else:
            if int(p2_choice) in range(1,10):
                choice2 = True
            else:
                print('Please select a valid position')
    return int(p2_choice)

# %%
# Function to replace Player 1 selection with X (not in loop)

def replace1(p1_choice,board):
    board =    [[1,2,3],[4,5,6],[7,8,9]] 
    
    
    if p1_choice == 1:
        board[0][0] = 'X'
    if p1_choice == 2:
        board[0][1] = 'X'
    if p1_choice == 3:
        board[0][2] = 'X'
    if p1_choice == 4:
        board[1][0] = 'X'
    if p1_choice == 5:
        board[1][1] = 'X'
    if p1_choice == 6:
        board[1][2] = 'X'
    if p1_choice == 7:
        board[2][0] = 'X'
    if p1_choice == 8:
        board[2][1] = 'X'
    if p1_choice == 9:
        board[2][2] = 'X'
        
    
       
    return board

# %%
# Function to replace player 2 selection with O 
def replace2(p2_choice,board):
  
    
  
    
    if p2_choice == 1:
        board[0][0] = 'O'          
    if p2_choice == 2:
        board[0][1] = 'O'
    if p2_choice == 3:
        board[0][2] = 'O'
    if p2_choice == 4:
        board[1][0] = 'O'
    if p2_choice == 5:
        board[1][1] = 'O'
    if p2_choice == 6:
        board[1][2] = 'O'
    if p2_choice == 7:
        board[2][0] = 'O'
    if p2_choice == 8:
        board[2][1] = 'O'
    if p2_choice == 9:
        board[2][2] = 'O'
        
    return board

# %%
# Winning conditions player 1


def wincheck_P1(board):
    
   
    
    if board[0][0] == "X" and board[0][1] == "X" and board[0][2] =="X":
        print("Congratulations!!!, Player 1 wins!")
        return False
        
    if board[1][0] == "X" and board[1][1] == "X" and board[1][2] =="X":
        print("Congratulations!!!, Player 1 wins!")
        return False
    if board[2][0] == "X" and board[2][1] == "X" and board[2][2] =="X":
        print("Congratulations!!!, Player 1 wins!")
        return False
      
    if board[0][0] == "X" and board[1][0] == "X" and board[2][0] =="X":
        print("Congratulations!!!, Player 1 wins!")
        return False
        
    if board[0][1] == "X" and board[1][1] == "X" and board[2][1] =="X":
        print("Congratulations!!!, Player 1 wins!")
        return False
        
    if board[0][2] == "X" and board[1][2] == "X" and board[2][2] =="X":
        print("Congratulations!!!, Player 1 wins!")
        return False
        
    if board[0][0] == "X" and board[1][1] == "X" and board[2][2] =="X":
        print("Congratulations!!!, Player 1 wins!")
        return False
     
    if board[0][2] == "X" and board[1][1] == "X" and board[2][0] =="X":
        print("Congratulations!!!, Player 1 wins!")
        return False
        
    else:
        return True

# %%
# Winning conditions player 2


def wincheck_P2(board):
    
    
    if board[0][0] == "O" and board[0][1] == "O" and board[0][2] =="O":
        print("Congratulations!!!, Player 2 wins!")
        return False
        
    elif board[1][0] == "O" and board[1][1] == "O" and board[1][2] =="O":
        print("Congratulations!!!, Player 2 wins!")
        return False
       
    elif board[2][0] == "O" and board[2][1] == "O" and board[2][2] =="O":
        print("Congratulations!!!, Player 2 wins!")
        return False
       
    elif board[0][0] == "O" and board[1][0] == "O" and board[2][0] =="O":
        print("Congratulations!!!, Player 2 wins!")
        return False
        
    elif board[0][1] == "O" and board[1][1] == "O" and board[2][1] =="O":
        print("Congratulations!!!, Player 2 wins!")
        return False
       
    elif board[0][2] == "O" and board[1][2] == "O" and board[2][2] =="O":
        print("Congratulations!!!, Player 2 wins!")
        return False
        
    elif board[0][0] == "O" and board[1][1] == "O" and board[2][2] =="O":
        print("Congratulations!!!, Player 2 wins!")
        return False
        
    elif board[0][2] == "O" and board[1][1] == "O" and board[2][0] =="O":
        print("Congratulations!!!, Player 2 wins!")
        return False
        
    
    else:
        return True

# %%
# Function to replace Player 1 selection with X (in loop)  
def replace3(p1_choice,board):
    
    
    
    if p1_choice == 1:
        board[0][0] = 'X'
    if p1_choice == 2:
        board[0][1] = 'X'
    if p1_choice == 3:
        board[0][2] = 'X'
    if p1_choice == 4:
        board[1][0] = 'X'
    if p1_choice == 5:
        board[1][1] = 'X'
    if p1_choice == 6:
        board[1][2] = 'X'
    if p1_choice == 7:
        board[2][0] = 'X'
    if p1_choice == 8:
        board[2][1] = 'X'
    if p1_choice == 9:
        board[2][2] = 'X'
        
    
       
    return board

# %%
# Game logic 
playon = True 
from IPython.display import clear_output
      
rules()
board1 = boards(board)
p1_choice = user_choice1()
clear_output()
board2 = replace1(p1_choice,board1)
boards(board2)
while playon:
    
    
    p2_choice = user_choice2()
    clear_output()
    board3 = replace2(p2_choice,board2)
    boards(board3)
    if wincheck_P2(board3) == False:
        break 
    p1_choice = user_choice1()
    clear_output()
    board4 = replace3(p1_choice,board3)
    boards(board4)
    if wincheck_P1(board4) == False:
        break
# Out:
# X X X
# O O X
# X O O
# Congratulations!!!, Player 1 wins!
